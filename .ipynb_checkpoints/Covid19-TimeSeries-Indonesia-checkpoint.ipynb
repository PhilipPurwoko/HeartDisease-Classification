# %% [markdown]
# # Overview
# **Sumber**
#
# Hendratno, “COVID-19 Indonesia Dataset.” Kaggle, doi: 10.34740/KAGGLE/DSV/1314265. (https://www.kaggle.com/hendratno/covid19-indonesia)
#
# **Context**
#
# The COVID-19 dataset in Indonesia was created to find out various factors that could be taken into consideration in decision making related to the level of stringency in each province in Indonesia.
#
# **Content**
#
# Data compiled based on time series, both on a country level (Indonesia), and on a province level. If needed in certain provinces, it might also be provided at the city / regency level. Demographic data is also available, as well as calculations between demographic data and COVID-19 pandemic data.
#
# **Acknowledgements**
#
# Thank you to those who have provided data openly so that we can compile it into a dataset here, which is as follows: covid19.go.id, kemendagri.go.id, bps.go.id, and bnpb-inacovid19.hub.arcgis.com
#
# **About this file**
# The COVID-19 pandemic dataset in Indonesia, time series. This dataset is a compilation of various open data sources, including: covid19.go.id (pandemic data), kemendagri.go.id (demographic data), bps.go.id (demographic data), as well as some calculations of the relationship of the data.
#
# This dataset contains a time series of COVID-19 pandemic events in Indonesia, at the country level to province level. If possible, in the future I will provide it to the city/regency level.

# %% [markdown]
# # Import Standard Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Persiapan Data

# %%
df = pd.read_csv('data/covid19-timeseries.csv',parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date Location ISO Code     Location  New Cases  New Deaths  \
# 0 2020-03-01             ID-JK  DKI Jakarta          3           0
# 1 2020-03-01             ID-JB   Jawa Barat          3           0
# 2 2020-03-02             ID-JK  DKI Jakarta          2           0
# 3 2020-03-02               IDN    Indonesia          2           0
# 4 2020-03-02             ID-JB   Jawa Barat          0           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 3          501            20
# 1              0                 3            3             5
# 2              0                 2          503            20
# 3              0                 2            2             0
# 4              0                 0            3             5
#
#    Total Recovered  ...   Longitude  Latitude  New Cases per Million  \
# 0               39  ...  106.836118 -6.204699                   0.28
# 1                4  ...  107.603708 -6.920432                   0.07
# 2               39  ...  106.836118 -6.204699                   0.18
# 3                0  ...  113.921327 -0.789275                   0.01
# 4                4  ...  107.603708 -6.920432                   0.00
#
#   Total Cases per Million New Deaths per Million Total Deaths per Million  \
# 0                   46.19                    0.0                     1.84
# 1                    0.07                    0.0                     0.11
# 2                   46.38                    0.0                     1.84
# 3                    0.01                    0.0                     0.00
# 4                    0.07                    0.0                     0.11
#
#   Case Fatality Rate Case Recovered Rate Growth Factor of New Cases  \
# 0              3.99%               7.78%                        NaN
# 1            166.67%             133.33%                        NaN
# 2              3.98%               7.75%                       0.67
# 3              0.00%               0.00%                        NaN
# 4            166.67%             133.33%                       0.00
#
#    Growth Factor of New Deaths
# 0                          NaN
# 1                          NaN
# 2                          1.0
# 3                          NaN
# 4                          1.0
#
# [5 rows x 37 columns]

# %%
df.head().T
# Out:
#                                                   0                    1  \
# Date                            2020-03-01 00:00:00  2020-03-01 00:00:00
# Location ISO Code                             ID-JK                ID-JB
# Location                                DKI Jakarta           Jawa Barat
# New Cases                                         3                    3
# New Deaths                                        0                    0
# New Recovered                                     0                    0
# New Active Cases                                  3                    3
# Total Cases                                     501                    3
# Total Deaths                                     20                    5
# Total Recovered                                  39                    4
# Total Active Cases                              442                   -6
# Location Level                             Province             Province
# City or Regency                                 NaN                  NaN
# Province                                DKI Jakarta           Jawa Barat
# Country                                   Indonesia            Indonesia
# Continent                                      Asia                 Asia
# Island                                         Jawa                 Jawa
# Time Zone                                 UTC+07:00            UTC+07:00
# Special Status               Daerah Khusus Ibu Kota                  NaN
# Total Regencies                                   1                   18
# Total Cities                                      5                    9
# Total Districts                                  44                  627
# Total Urban Villages                            267                  645
# Total Rural Villages                            NaN                 5312
# Area (km2)                                      664                35378
# Population                                 10846145             45161325
# Population Density                          16334.3              1276.55
# Longitude                                   106.836              107.604
# Latitude                                    -6.2047             -6.92043
# New Cases per Million                          0.28                 0.07
# Total Cases per Million                       46.19                 0.07
# New Deaths per Million                            0                    0
# Total Deaths per Million                       1.84                 0.11
# Case Fatality Rate                            3.99%              166.67%
# Case Recovered Rate                           7.78%              133.33%
# Growth Factor of New Cases                      NaN                  NaN
# Growth Factor of New Deaths                     NaN                  NaN
#
#                                                   2                    3  \
# Date                            2020-03-02 00:00:00  2020-03-02 00:00:00
# Location ISO Code                             ID-JK                  IDN
# Location                                DKI Jakarta            Indonesia
# New Cases                                         2                    2
# New Deaths                                        0                    0
# New Recovered                                     0                    0
# New Active Cases                                  2                    2
# Total Cases                                     503                    2
# Total Deaths                                     20                    0
# Total Recovered                                  39                    0
# Total Active Cases                              444                    2
# Location Level                             Province              Country
# City or Regency                                 NaN                  NaN
# Province                                DKI Jakarta                  NaN
# Country                                   Indonesia            Indonesia
# Continent                                      Asia                 Asia
# Island                                         Jawa                  NaN
# Time Zone                                 UTC+07:00                  NaN
# Special Status               Daerah Khusus Ibu Kota                  NaN
# Total Regencies                                   1                  416
# Total Cities                                      5                   98
# Total Districts                                  44                 7230
# Total Urban Villages                            267                 8488
# Total Rural Villages                            NaN                74953
# Area (km2)                                      664              1916907
# Population                                 10846145            265185520
# Population Density                          16334.3               138.34
# Longitude                                   106.836              113.921
# Latitude                                    -6.2047            -0.789275
# New Cases per Million                          0.18                 0.01
# Total Cases per Million                       46.38                 0.01
# New Deaths per Million                            0                    0
# Total Deaths per Million                       1.84                    0
# Case Fatality Rate                            3.98%                0.00%
# Case Recovered Rate                           7.75%                0.00%
# Growth Factor of New Cases                     0.67                  NaN
# Growth Factor of New Deaths                       1                  NaN
#
#                                                4
# Date                         2020-03-02 00:00:00
# Location ISO Code                          ID-JB
# Location                              Jawa Barat
# New Cases                                      0
# New Deaths                                     0
# New Recovered                                  0
# New Active Cases                               0
# Total Cases                                    3
# Total Deaths                                   5
# Total Recovered                                4
# Total Active Cases                            -6
# Location Level                          Province
# City or Regency                              NaN
# Province                              Jawa Barat
# Country                                Indonesia
# Continent                                   Asia
# Island                                      Jawa
# Time Zone                              UTC+07:00
# Special Status                               NaN
# Total Regencies                               18
# Total Cities                                   9
# Total Districts                              627
# Total Urban Villages                         645
# Total Rural Villages                        5312
# Area (km2)                                 35378
# Population                              45161325
# Population Density                       1276.55
# Longitude                                107.604
# Latitude                                -6.92043
# New Cases per Million                          0
# Total Cases per Million                     0.07
# New Deaths per Million                         0
# Total Deaths per Million                    0.11
# Case Fatality Rate                       166.67%
# Case Recovered Rate                      133.33%
# Growth Factor of New Cases                     0
# Growth Factor of New Deaths                    1

# %%
df['Location'].unique(),len(df['Location'].unique())
# Out:
# (array(['DKI Jakarta', 'Jawa Barat', 'Indonesia', 'Banten',
#         'Sulawesi Tenggara', 'Kalimantan Timur',
#         'Daerah Istimewa Yogyakarta', 'Sumatera Utara', 'Jawa Tengah',
#         'Jawa Timur', 'Sulawesi Selatan', 'Maluku', 'Papua',
#         'Maluku Utara', 'Aceh', 'Kalimantan Tengah', 'Lampung',
#         'Sulawesi Tengah', 'Sumatera Barat', 'Papua Barat',
#         'Kalimantan Utara', 'Sulawesi Barat', 'Sumatera Selatan', 'Bali',
#         'Kalimantan Barat', 'Riau', 'Jambi', 'Kalimantan Selatan',
#         'Kepulauan Bangka Belitung', 'Kepulauan Riau', 'Bengkulu',
#         'Nusa Tenggara Barat', 'Sulawesi Utara', 'Nusa Tenggara Timur',
#         'Gorontalo'], dtype=object),
#  35)

# %%
parameter = ['Date','Total Cases','Total Deaths','Total Recovered','Total Active Cases','Case Fatality Rate','Case Recovered Rate']

# %%
dataframe = pd.DataFrame(columns=parameter)

# %%
dataframe.head()
# Out:
# Empty DataFrame
# Columns: [Date, Total Cases, Total Deaths, Total Recovered, Total Active Cases, Case Fatality Rate, Case Recovered Rate]
# Index: []

# %%
for param in parameter:
    dataframe[param] = df[param][df.Location == 'Indonesia']

# %%
dataframe.reset_index(inplace=True,drop=True)

# %%
dataframe.tail()
# Out:
#           Date  Total Cases  Total Deaths  Total Recovered  \
# 123 2020-07-03        60695          3036            27568
# 124 2020-07-04        62142          3089            28219
# 125 2020-07-05        63749          3171            29105
# 126 2020-07-06        64958          3241            29919
# 127 2020-07-07        66226          3309            30785
#
#      Total Active Cases Case Fatality Rate Case Recovered Rate
# 123               30091              5.00%              45.42%
# 124               30834              4.97%              45.41%
# 125               31473              4.97%              45.66%
# 126               31798              4.99%              46.06%
# 127               32132              5.00%              46.48%

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 128 non-null    datetime64[ns]
#  1   Total Cases          128 non-null    int64
#  2   Total Deaths         128 non-null    int64
#  3   Total Recovered      128 non-null    int64
#  4   Total Active Cases   128 non-null    int64
#  5   Case Fatality Rate   128 non-null    object
#  6   Case Recovered Rate  128 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 7.1+ KB

# %% [markdown]
# # Konversi Data ke Numerical

# %%
percent_data = ['Case Fatality Rate','Case Recovered Rate']

# %%
for col in percent_data:
    temp = []
    for row in range(len(dataframe[col])):
        temp.append(float(dataframe[col][row][:-1]))
    dataframe.drop([col],axis=1,inplace=True)
    dataframe[col] = temp

# %%
dataframe.tail()
# Out:
#           Date  Total Cases  Total Deaths  Total Recovered  \
# 123 2020-07-03        60695          3036            27568
# 124 2020-07-04        62142          3089            28219
# 125 2020-07-05        63749          3171            29105
# 126 2020-07-06        64958          3241            29919
# 127 2020-07-07        66226          3309            30785
#
#      Total Active Cases  Case Fatality Rate  Case Recovered Rate
# 123               30091                5.00                45.42
# 124               30834                4.97                45.41
# 125               31473                4.97                45.66
# 126               31798                4.99                46.06
# 127               32132                5.00                46.48

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 128 non-null    datetime64[ns]
#  1   Total Cases          128 non-null    int64
#  2   Total Deaths         128 non-null    int64
#  3   Total Recovered      128 non-null    int64
#  4   Total Active Cases   128 non-null    int64
#  5   Case Fatality Rate   128 non-null    float64
#  6   Case Recovered Rate  128 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 7.1 KB

# %% [markdown]
# # Machine Learning Model
