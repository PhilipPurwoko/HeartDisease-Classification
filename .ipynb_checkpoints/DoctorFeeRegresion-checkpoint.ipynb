# %% [markdown]
# # 1. Persiapkan Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_excel('data/doctor-fee.xlsx')
dataframe = dataframe.drop('Miscellaneous_Info',axis=1)

# %%
dataframe.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  Fees
# 0           Kakkanad, Ernakulam       Homeopath   100
# 1         Whitefield, Bangalore        Ayurveda   350
# 2    Mathikere - BEL, Bangalore  ENT Specialist   300
# 3  Bannerghatta Road, Bangalore        Ayurveda   250
# 4         Keelkattalai, Chennai        Ayurveda   250

# %%
def describe(dataframe):
    for col in list(dataframe):
        print(f'{col} : {len(dataframe[col].unique())} Unique Values, {len([i for i in dataframe[col] if type(i) == float])} NaN')

# %%
describe(dataframe)
# Out:
# Qualification : 1420 Unique Values, 0 NaN
# Experience : 64 Unique Values, 0 NaN
# Rating : 52 Unique Values, 3302 NaN
# Place : 878 Unique Values, 25 NaN
# Profile : 6 Unique Values, 0 NaN
# Fees : 40 Unique Values, 0 NaN

# %% [markdown]
# # 2. Mengisi Data Kosong Dengan Nilai Rata-Rata

# %%
for_mean = []
for rate in dataframe['Rating']:
    try:
        for_mean.append(int(rate[:-1]))
    except TypeError:
        pass

# %%
np.mean(for_mean)
# Out:
# 94.64347499059797

# %%
rating = []
for rate in dataframe['Rating']:
    try:
        rating.append(float(rate[:-1]))
    except TypeError:
        rating.append(94.64347499059797)

# %%
dataframe = dataframe.drop('Rating',axis=1)

# %%
dataframe['Rating'] = rating

# %%
dataframe.head()
# Out:
#                     Qualification           Experience  \
# 0           BHMS, MD - Homeopathy  24 years experience
# 1    BAMS, MD - Ayurveda Medicine  12 years experience
# 2  MBBS, MS - Otorhinolaryngology   9 years experience
# 3             BSc - Zoology, BAMS  12 years experience
# 4                            BAMS  20 years experience
#
#                           Place         Profile  Fees      Rating
# 0           Kakkanad, Ernakulam       Homeopath   100  100.000000
# 1         Whitefield, Bangalore        Ayurveda   350   98.000000
# 2    Mathikere - BEL, Bangalore  ENT Specialist   300   94.643475
# 3  Bannerghatta Road, Bangalore        Ayurveda   250   94.643475
# 4         Keelkattalai, Chennai        Ayurveda   250  100.000000

# %% [markdown]
# # 3. Konversi Data ke Numerical

# %%
'4 years experience'[:-17]
# Out:
# '4'

# %%
experience = []
for exp in dataframe['Experience']:
    exp = int(exp[:-17])
    experience.append(exp)

# %%
dataframe = dataframe.drop('Experience',axis=1)

# %%
dataframe['Experience'] = experience

# %%
dataframe.head()
# Out:
#                     Qualification                         Place  \
# 0           BHMS, MD - Homeopathy           Kakkanad, Ernakulam
# 1    BAMS, MD - Ayurveda Medicine         Whitefield, Bangalore
# 2  MBBS, MS - Otorhinolaryngology    Mathikere - BEL, Bangalore
# 3             BSc - Zoology, BAMS  Bannerghatta Road, Bangalore
# 4                            BAMS         Keelkattalai, Chennai
#
#           Profile  Fees      Rating  Experience
# 0       Homeopath   100  100.000000          24
# 1        Ayurveda   350   98.000000          12
# 2  ENT Specialist   300   94.643475           9
# 3        Ayurveda   250   94.643475          12
# 4        Ayurveda   250  100.000000          20

# %% [markdown]
# # 4. Menghapus Data Kosong

# %%
# 25 Baris akan dihapus, jika kolom Place == NaN
describe(dataframe)
# Out:
# Qualification : 1420 Unique Values, 0 NaN
# Place : 878 Unique Values, 25 NaN
# Profile : 6 Unique Values, 0 NaN
# Fees : 40 Unique Values, 0 NaN
# Rating : 52 Unique Values, 5961 NaN
# Experience : 64 Unique Values, 0 NaN

# %%
dataframe.dropna(subset = ['Place'], inplace=True)

# %%
describe(dataframe)
# Out:
# Qualification : 1419 Unique Values, 0 NaN
# Place : 877 Unique Values, 0 NaN
# Profile : 6 Unique Values, 0 NaN
# Fees : 40 Unique Values, 0 NaN
# Rating : 52 Unique Values, 5936 NaN
# Experience : 64 Unique Values, 0 NaN

# %%
dataframe.head()
# Out:
#                     Qualification                         Place  \
# 0           BHMS, MD - Homeopathy           Kakkanad, Ernakulam
# 1    BAMS, MD - Ayurveda Medicine         Whitefield, Bangalore
# 2  MBBS, MS - Otorhinolaryngology    Mathikere - BEL, Bangalore
# 3             BSc - Zoology, BAMS  Bannerghatta Road, Bangalore
# 4                            BAMS         Keelkattalai, Chennai
#
#           Profile  Fees      Rating  Experience
# 0       Homeopath   100  100.000000          24
# 1        Ayurveda   350   98.000000          12
# 2  ENT Specialist   300   94.643475           9
# 3        Ayurveda   250   94.643475          12
# 4        Ayurveda   250  100.000000          20

# %% [markdown]
# # 5. Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
for col in ['Qualification','Place','Profile']:
    dataframe[col] = encoder.fit_transform(dataframe[col])

# %%
dataframe.head()
# Out:
#    Qualification  Place  Profile  Fees      Rating  Experience
# 0            401    299        5   100  100.000000          24
# 1             73    866        0   350   98.000000          12
# 2           1134    457        3   300   94.643475           9
# 3            464     68        0   250   94.643475          12
# 4             10    337        0   250  100.000000          20

# %%
describe(dataframe)
# Out:
# Qualification : 1419 Unique Values, 0 NaN
# Place : 877 Unique Values, 0 NaN
# Profile : 6 Unique Values, 0 NaN
# Fees : 40 Unique Values, 0 NaN
# Rating : 52 Unique Values, 5936 NaN
# Experience : 64 Unique Values, 0 NaN

# %% [markdown]
# # 6. Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
data = dataframe.drop('Fees',axis=1)
fees = dataframe['Fees']

# %%
x_train,x_test,y_train,y_test = train_test_split(data,fees,test_size=0.2)

# %% [markdown]
# # 7. Machine Learning Model

# %% [markdown]
# <img src="ml_map.png">

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict([[74,68,3,90.00,10]])
# Out:
# array([281.43322265])

# %%
prediction = model.predict(x_test)

# %% [markdown]
# # 8. Evaluation Metrics
# Evauation Metrics for Regresion are :
# * Mean Absolute Error (MAE)
# * Root Mean Squared Error (RMSE)
# * Mean Absolute Percentage Error (MAPE)
# * R-Squared Score

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
def evaluateModel(y_true,y_pred):
    print('Your Evaluation Metrics')
    print(f'Mean Absolute Error (MAE) : {mean_absolute_error(y_true,y_pred)}')
    print(f'Root Mean Squared Error (RMSE) : {mean_squared_error(y_true,y_pred)}')
    print(f'R-Squared Score (r2) : {r2_score(y_true,y_pred)}')

# %%
evaluateModel(y_test,prediction)
# Out:
# Your Evaluation Metrics
# Mean Absolute Error (MAE) : 145.3335249106211
# Root Mean Squared Error (RMSE) : 32396.359807694913
# R-Squared Score (r2) : 0.07683776366590833

# %%
def visualize(y_true,y_pred,title=None):
    plt.figure(figsize=(20,5))
    plt.title(title)
    plt.plot(range(len(y_true)),y_true,label='True Value')
    plt.plot(range(len(y_pred)),y_pred,label='Prediction')
    plt.legend()
    plt.show()

# %%
visualize(y_test,prediction)

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
# Mencari korelasi (hubungan) variabel dengan fees
def corelate(data,fees,col):
    plt.scatter(fees,data[col])
    plt.xlabel('Fees')
    plt.ylabel(col)
    plt.title(f'Corelation Between Fees & {col}')
    plt.show()

# %%
for i in ['Experience','Rating','Qualification','Place','Profile']:
    corelate(x_test,y_test,i)

# %% [markdown]
# # 9. Meningkatkan Model

# %%
# Mencoba menggunakan berbagai model
from sklearn.linear_model import LinearRegression,LogisticRegression,Lasso,Ridge
linearModels = ['LinearRegression','LogisticRegression','Lasso','Ridge']

# %%
for mod in linearModels:
    print(f'Using {mod}')
    modl = eval(mod)()
    modl.fit(x_train,y_train)
    pred = modl.predict(x_test)
    evaluateModel(y_test,pred)
    visualize(y_test,pred,mod)
# Out:
# Using LinearRegression
# Your Evaluation Metrics
# Mean Absolute Error (MAE) : 145.3335249106211
# Root Mean Squared Error (RMSE) : 32396.359807694913
# R-Squared Score (r2) : 0.07683776366590833
# Using LogisticRegression
# C:\Users\PHILIP\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\PHILIP\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Your Evaluation Metrics
# Mean Absolute Error (MAE) : 180.9124579124579
# Root Mean Squared Error (RMSE) : 61298.67508417508
# R-Squared Score (r2) : -0.7467586577916316
# Using Lasso
# Your Evaluation Metrics
# Mean Absolute Error (MAE) : 145.3375197991683
# Root Mean Squared Error (RMSE) : 32398.70520445044
# R-Squared Score (r2) : 0.07677092956088005
# Using Ridge
# Your Evaluation Metrics
# Mean Absolute Error (MAE) : 145.33350481705642
# Root Mean Squared Error (RMSE) : 32396.35388402808
# R-Squared Score (r2) : 0.07683793246590787
